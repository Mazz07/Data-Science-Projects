# %% [markdown]
# # keras tuner - decide number of Hidden Layers and Hidden Neurons

# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch

# %%
df = pd.read_csv(r'F:\Data Science Projects\Deep Learning\Real_Combine.csv')
df.head()
#This information is Air Quality index-prediction.
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
x = df.iloc[:,:-1] #independent features
y = df.iloc[:,-1] #dependent features

# %% [markdown]
# # Hyperparameters
# 1.How many number of hidden layers we should have?
# 2.how many number of neurons we should have in hidden layers?
# 3.Learninig Rate

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers',2,20)):
        model.add(layers.Dense(units = hp.Int('units_'+str(i),
                                             min_value=32,
                                             max_value=512,
                                             step=32),
                              activation='relu'))
    model.add(layers.Dense(1,activation='linear'))
    model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate',[1e-2,1e-3,1e-4])),
        loss = 'mean_absolute_error',metrics=['mean_absolute_error'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective = 'val_mean_absolute_error',
    max_trials = 5,
    executions_per_trial=3,
    directory='project',
    project_name = 'Air Quality Index')
# Out:
# INFO:tensorflow:Reloading Tuner from project\Air Quality Index\tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 18
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_10 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_11 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_12 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_13 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_14 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_15 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=20)

# %%
tuner.search(x_train,y_train,epochs=5,validation_data=(x_test,y_test))
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project\Air Quality Index
# Showing 10 best trials
# Objective(name="val_mean_absolute_error", direction="min")
#
# Trial 4 summary
# Hyperparameters:
# num_layers: 9
# units_0: 64
# units_1: 384
# learning_rate: 0.01
# units_2: 96
# units_3: 352
# units_4: 224
# units_5: 160
# units_6: 320
# units_7: 192
# units_8: 384
# units_9: 160
# units_10: 352
# units_11: 448
# units_12: 64
# units_13: 320
# units_14: 128
# units_15: 512
# Traceback (most recent call last):
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\tuner.py", line 213, in _build_and_fit_model
#     model = self._try_build(hp)
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\tuner.py", line 155, in _try_build
#     model = self._build_hypermodel(hp)
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "C:\Users\dell\AppData\Local\Temp\ipykernel_4184\1501139127.py", line 4, in build_model
#     model.add(layers.Dense(units = hp.Int(int(units_)+int(i),
# NameError: name 'units_' is not defined
#
#
# Trial 0 summary
# Hyperparameters:
# num_layers: 10
# units_0: 320
# units_1: 352
# learning_rate: 0.01
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# units_9: 32
# Score: nan
#
# Trial 1 summary
# Hyperparameters:
# num_layers: 6
# units_0: 256
# units_1: 512
# learning_rate: 0.0001
# units_2: 320
# units_3: 416
# units_4: 448
# units_5: 416
# units_6: 512
# units_7: 256
# units_8: 384
# units_9: 384
# Score: nan
#
# Trial 3 summary
# Hyperparameters:
# num_layers: 2
# units_0: 96
# units_1: 224
# learning_rate: 0.01
# units_2: 352
# units_3: 448
# units_4: 64
# units_5: 448
# units_6: 480
# units_7: 480
# units_8: 64
# units_9: 288
# units_10: 32
# units_11: 512
# units_12: 288
# units_13: 192
# units_14: 320
# units_15: 160
# Traceback (most recent call last):
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\tuner.py", line 213, in _build_and_fit_model
#     model = self._try_build(hp)
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\tuner.py", line 155, in _try_build
#     model = self._build_hypermodel(hp)
#   File "c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\keras_tuner\engine\tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "C:\Users\dell\AppData\Local\Temp\ipykernel_4184\1501139127.py", line 4, in build_model
#     model.add(layers.Dense(units = hp.Int(int(units_)+int(i),
# NameError: name 'units_' is not defined
#
#
# Trial 2 summary
# Hyperparameters:
# num_layers: 16
# units_0: 416
# units_1: 448
# learning_rate: 0.0001
# units_2: 512
# units_3: 416
# units_4: 512
# units_5: 416
# units_6: 448
# units_7: 96
# units_8: 224
# units_9: 256
# units_10: 32
# units_11: 32
# units_12: 32
# units_13: 32
# units_14: 32
# units_15: 32
